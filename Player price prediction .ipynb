# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split as split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fdata=pd.read_csv("D:/NMIMS/SEM 4/SM/football/Dataset/football.csv")

# %%
data=fdata.copy()

# %%
data
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 456  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 457       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 458            Sam Byram  West+Ham   23       RB             3           4.5
# 459      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 460         Diafra Sakho  West+Ham   27       CF             1          10.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0          4329       12.0  17.10%         264     3.0           Chile
# 1          4395        9.5   5.60%         167     2.0         Germany
# 2          1529        5.5   5.90%         134     2.0  Czech Republic
# 3          2393        7.5   1.50%         122     1.0         England
# 4           912        6.0   0.70%         121     2.0          France
# ..          ...        ...     ...         ...     ...             ...
# 456         288        4.5   0.40%          38     2.0     Switzerland
# 457         199        4.5   0.20%          34     4.0        Congo DR
# 458         198        4.5   0.30%          29     1.0         England
# 459         412        4.5   5.90%          16     1.0         England
# 460         214        5.5   0.10%          12     4.0         Senegal
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 0              0        4        1         1            0
# 1              0        4        1         1            0
# 2              0        6        1         1            0
# 3              0        4        1         1            0
# 4              0        4        1         1            0
# ..           ...      ...      ...       ...          ...
# 456            0        1       20         0            1
# 457            0        2       20         0            1
# 458            0        2       20         0            0
# 459            0        1       20         0            1
# 460            0        3       20         0            0
#
# [461 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461 entries, 0 to 460
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          461 non-null    object
#  1   club          461 non-null    object
#  2   age           461 non-null    int64
#  3   position      461 non-null    object
#  4   position_cat  461 non-null    int64
#  5   market_value  461 non-null    float64
#  6   page_views    461 non-null    int64
#  7   fpl_value     461 non-null    float64
#  8   fpl_sel       461 non-null    object
#  9   fpl_points    461 non-null    int64
#  10  region        460 non-null    float64
#  11  nationality   461 non-null    object
#  12  new_foreign   461 non-null    int64
#  13  age_cat       461 non-null    int64
#  14  club_id       461 non-null    int64
#  15  big_club      461 non-null    int64
#  16  new_signing   461 non-null    int64
# dtypes: float64(3), int64(9), object(5)
# memory usage: 61.4+ KB

# %%
data.describe()
# Out:
#               age  position_cat  market_value   page_views   fpl_value  \
# count  461.000000    461.000000    461.000000   461.000000  461.000000
# mean    26.804772      2.180043     11.012039   763.776573    5.447939
# std      3.961892      1.000061     12.257403   931.805757    1.346695
# min     17.000000      1.000000      0.050000     3.000000    4.000000
# 25%     24.000000      1.000000      3.000000   220.000000    4.500000
# 50%     27.000000      2.000000      7.000000   460.000000    5.000000
# 75%     30.000000      3.000000     15.000000   896.000000    5.500000
# max     38.000000      4.000000     75.000000  7664.000000   12.500000
#
#        fpl_points      region  new_foreign     age_cat     club_id  \
# count  461.000000  460.000000   461.000000  461.000000  461.000000
# mean    57.314534    1.993478     0.034707    3.206074   10.334056
# std     53.113811    0.957689     0.183236    1.279795    5.726475
# min      0.000000    1.000000     0.000000    1.000000    1.000000
# 25%      5.000000    1.000000     0.000000    2.000000    6.000000
# 50%     51.000000    2.000000     0.000000    3.000000   10.000000
# 75%     94.000000    2.000000     0.000000    4.000000   15.000000
# max    264.000000    4.000000     1.000000    6.000000   20.000000
#
#          big_club  new_signing
# count  461.000000   461.000000
# mean     0.303688     0.145336
# std      0.460349     0.352822
# min      0.000000     0.000000
# 25%      0.000000     0.000000
# 50%      0.000000     0.000000
# 75%      1.000000     0.000000
# max      1.000000     1.000000

# %%
data["market_value"].max()
# Out:
# 75.0

# %%
data["club"].unique()
# Out:
# array(['Arsenal', 'Bournemouth', 'Brighton+and+Hove', 'Burnley',
#        'Chelsea', 'Crystal+Palace', 'Everton', 'Huddersfield',
#        'Leicester+City', 'Liverpool', 'Manchester+City',
#        'Manchester+United', 'Newcastle+United', 'Southampton',
#        'Stoke+City', 'Swansea', 'Tottenham', 'Watford', 'West+Brom',
#        'West+Ham'], dtype=object)

# %%
dup=data.duplicated()
print(dup.sum())
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# name            0
# club            0
# age             0
# position        0
# position_cat    0
# market_value    0
# page_views      0
# fpl_value       0
# fpl_sel         0
# fpl_points      0
# region          1
# nationality     0
# new_foreign     0
# age_cat         0
# club_id         0
# big_club        0
# new_signing     0
# dtype: int64

# %%
data[data["region"].isnull()]
# Out:
#              name          club  age position  position_cat  market_value  \
# 188  Steve Mounie  Huddersfield   22       CF             1           5.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 188          56        6.0   0.60%           0     NaN       Benin
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 188            0        2        8         0            0

# %%
data.loc[188,:]
# Out:
# name            Steve Mounie
# club            Huddersfield
# age                       22
# position                  CF
# position_cat               1
# market_value             5.5
# page_views                56
# fpl_value                6.0
# fpl_sel                0.60%
# fpl_points                 0
# region                   NaN
# nationality            Benin
# new_foreign                0
# age_cat                    2
# club_id                    8
# big_club                   0
# new_signing                0
# Name: 188, dtype: object

# %%
data['region'] = data['region'].replace(np.nan, 4)

# %% [markdown]
# EDA

# %%
data.dtypes
# Out:
# name             object
# club             object
# age               int64
# position         object
# position_cat      int64
# market_value    float64
# page_views        int64
# fpl_value       float64
# fpl_sel          object
# fpl_points        int64
# region          float64
# nationality      object
# new_foreign       int64
# age_cat           int64
# club_id           int64
# big_club          int64
# new_signing       int64
# dtype: object

# %%
sns.scatterplot(data=data,x='age',y='market_value')
# Out:
# <AxesSubplot:xlabel='age', ylabel='market_value'>

# %%
sns.barplot(data=data,x='age',y='club')
# Out:
# <AxesSubplot:xlabel='age', ylabel='club'>

# %%
sns.barplot(data=data,x='position_cat',y='market_value')
# Out:
# <AxesSubplot:xlabel='position_cat', ylabel='market_value'>

# %%
sns.barplot(data=data,x='club',y='market_value')
# Out:
# <AxesSubplot:xlabel='club', ylabel='market_value'>

# %%
data.corr(method='pearson')
# Out:
#                    age  position_cat  market_value  page_views  fpl_value  \
# age           1.000000      0.220678     -0.132396   -0.048682  -0.097659
# position_cat  0.220678      1.000000     -0.217637   -0.279432  -0.491800
# market_value -0.132396     -0.217637      1.000000    0.739657   0.788653
# page_views   -0.048682     -0.279432      0.739657    1.000000   0.730640
# fpl_value    -0.097659     -0.491800      0.788653    0.730640   1.000000
# fpl_points    0.187785     -0.084682      0.615155    0.542464   0.618837
# region        0.080379     -0.067439      0.099114    0.027441   0.083883
# new_foreign  -0.125400      0.001415      0.098056   -0.049725   0.108650
# age_cat       0.972199      0.196853     -0.117682   -0.041672  -0.082056
# club_id      -0.002868     -0.016599     -0.046068   -0.092409  -0.060884
# big_club     -0.123566      0.017915      0.593483    0.502982   0.423556
# new_signing  -0.079190     -0.105127      0.131321    0.127249   0.098314
#
#               fpl_points    region  new_foreign   age_cat   club_id  big_club  \
# age             0.187785  0.080379    -0.125400  0.972199 -0.002868 -0.123566
# position_cat   -0.084682 -0.067439     0.001415  0.196853 -0.016599  0.017915
# market_value    0.615155  0.099114     0.098056 -0.117682 -0.046068  0.593483
# page_views      0.542464  0.027441    -0.049725 -0.041672 -0.092409  0.502982
# fpl_value       0.618837  0.083883     0.108650 -0.082056 -0.060884  0.423556
# fpl_points      1.000000 -0.011569    -0.204837  0.176572  0.041094  0.280061
# region         -0.011569  1.000000     0.049800  0.085190  0.066483  0.035883
# new_foreign    -0.204837  0.049800     1.000000 -0.113998 -0.002786  0.080949
# age_cat         0.176572  0.085190    -0.113998  1.000000 -0.004668 -0.113835
# club_id         0.041094  0.066483    -0.002786 -0.004668  1.000000 -0.155667
# big_club        0.280061  0.035883     0.080949 -0.113835 -0.155667  1.000000
# new_signing     0.085720  0.174007    -0.078193 -0.076102  0.134085  0.035508
#
#               new_signing
# age             -0.079190
# position_cat    -0.105127
# market_value     0.131321
# page_views       0.127249
# fpl_value        0.098314
# fpl_points       0.085720
# region           0.174007
# new_foreign     -0.078193
# age_cat         -0.076102
# club_id          0.134085
# big_club         0.035508
# new_signing      1.000000

# %%
sns.heatmap(data.corr() , xticklabels= data.corr().columns , yticklabels= data.corr().columns)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
figsize = (20, 10)
fig, ax = plt.subplots(figsize=figsize)
sns.countplot(x='club',data=data, ax=ax)
plt.title("Rating")
# Out:
# Text(0.5, 1.0, 'Rating')

# %%
#data.drop(['name','club','position','nationality','fpl_sel'],axis=1,inplace=True)
data.drop(['fpl_sel'],axis=1,inplace=True)

# %%
X=data.drop("market_value",axis=1)

# %%
Y=data["market_value"]

# %%
X_train, X_test, Y_train, Y_test=split(X, Y, test_size = 0.25, random_state=0)

# %%
from sklearn.linear_model import LinearRegression as lgr
regressor=lgr()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
ypred=regressor.predict(X_test)

# %%
ypred
# Out:
# array([ 1.63701466e+01,  2.81217370e+00,  1.82749129e+01,  3.93598751e+00,
#         4.24717014e+00,  2.50459476e+00,  1.39205506e+01,  1.83571284e+01,
#         7.95182208e+00,  4.34377949e-03, -3.55831772e+00,  1.28344927e+01,
#         7.49407764e+00,  1.02745098e+01,  1.61838914e+01,  2.15274152e+01,
#         7.83565389e+00,  1.30667300e+01,  1.48822256e+01, -8.18291748e-01,
#         1.85832067e+01,  1.32945012e+01,  7.51843885e+00,  7.78179532e+00,
#         1.12622722e+01,  3.59474129e+00,  6.57273908e+00,  4.22640336e+01,
#         1.79363015e+01,  2.94537646e+00,  1.04820481e+01,  2.24129123e+01,
#         3.90493167e+00,  3.57686239e+00,  5.33444243e+00,  7.80412035e+00,
#         1.67867435e+01, -2.49548068e-02,  4.06227124e+00,  4.22557526e+00,
#        -1.35936680e+00,  1.48271608e+01,  1.10518451e+01,  1.30691871e+01,
#         2.65417599e+01,  3.04239071e+01, -1.68084350e+00,  1.08073217e+01,
#         1.18974677e+00,  1.35319391e+01,  2.54789687e+01,  7.87815204e+00,
#         9.69890327e+00,  9.01217159e+00,  2.07824424e+00,  8.74384420e+00,
#         7.52552582e+00, -3.28205791e+00,  7.71977147e+00,  9.84303586e+00,
#         4.43016368e+00,  4.39281439e+00,  1.13585970e+01, -4.43349230e-01,
#         2.98710559e+01,  1.10289503e+01,  2.02974634e+01,  4.76488184e+00,
#         1.16597234e+01,  6.39839339e-01,  1.61996933e+01,  5.21851602e+00,
#         1.72736461e+00,  2.47755787e+01,  8.17591844e-01, -5.38507204e-01,
#         9.08387463e+00, -5.89556873e-01,  1.72599442e+01,  6.35591355e+00,
#         5.78121456e+00, -4.32967916e+00,  6.60199566e+00,  2.52593954e+01,
#         7.12218542e+00, -2.06771159e+00,  2.65117061e+01,  9.31809111e+00,
#         2.35943465e+00,  1.54054976e+01,  3.74560169e+00,  1.49847844e+01,
#         2.14689398e+00,  2.53550873e+01,  1.01145932e+01,  1.97569037e+01,
#         9.87438108e+00,  5.75011822e-01,  1.21319674e+00, -1.56673163e+00,
#         1.02497708e+01,  1.99366602e+01,  2.28065068e+00,  1.82784249e+01,
#         1.42271359e+00,  1.87407880e+01,  1.06002619e+01,  4.29311146e+01,
#         8.52817747e+00,  8.10068362e+00,  2.06755048e+01,  4.12932568e+01,
#         2.42308310e+01,  1.29815717e+01,  1.83783910e+01,  7.02923764e+00])

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,ypred)
# Out:
# 0.7189516447988054

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,ypred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13052\2191444949.py in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(Y_test,ypred)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#     102     # No metrics support "multiclass-multioutput" format
#     103     if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 104         raise ValueError("{0} is not supported".format(y_type))
#     105
#     106     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported
